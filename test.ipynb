# %%
import import_ipynb
import  CompressionDGHV as dc
# Out:
# importing Jupyter notebook from CompressionDGHV.ipynb

# %% [markdown]
# # keygenaration

# %%
 λ=1
j=dc.keygeneration(λ)
λ=j[0]
ρ=j[1]
η=j[2]
γ=j[3]
τ=j[4]
ρρ=j[5]
α=j[6]
x_0=j[7]
delta=j[8]
se=j[9]
p=j[10]
# Out:
# enter security parameter12
# λ 12
# ρ 12
# η 144
# γ 248832
# τ 1728
# ρρ 144
# α 144
# Random integer from 2^(η-1) to 2^(η)
# secret key:  11396340549264812129714474985013396252244717
# delta [49163698649500948828294050407987515938136379713
#  63492317433076412538449395782526192021452343688
#  56972505925759781764053250264747890390595974477 ...
#  90789743670166531517003850951113956027965900071
#  90790210964120688847321903260817457766054999099
#  82476194581789488373109910313326643370672458842]

# %% [markdown]
# # plaintext

# %%
n=1
m=dc.plaintext(n)
# Out:
# Enter number of elements : 2
# plaintext [0 0]

# %% [markdown]
# # encryption

# %%
c=dc.enc(m,se,x_0,γ,τ,delta,ρρ,α)
# Out:
# ciphertext [-..., ...]

# %% [markdown]
# # decryption

# %%
d=dc.dec(c,p)
# Out:
# decription [0, 0]

# %% [markdown]
# # error decryption

# %%
dc.error(d,m)
# Out:
# error 0

# %% [markdown]
# # ADD

# %%
dc.ADD(c,p,m,x_0)
# Out:
# decription [1]
# saddc [1]
# saddm [0]
# error 1
# None

# %% [markdown]
# # mult

# %%
dc.mult(c,p,m,x_0)
# Out:
# -...
# decription [0]
# mullc [0]
# mul_m [0]
# error 0
# None
